# %% [markdown]
# # Earthmover.io arraylake ERA5
#
# My organization is mpocanes, my email is authentication.
# https://app.earthmover.io/mpocanes
#
# Access with arraylake and xarray (must be >2024 xarray).

# %%
from arraylake import Client

client = Client()
client.login()
# Out:
# Successfully refreshed tokens! Token stored at /Users/bmapes/.arraylake/token.json
# ╭───────────────────────────────────────────────── User Details ──────────────────────────────────────────────────╮
# │ Name: None None                                                                                                 │
# │ Email: bmapes@miami.edu                                                                                         │
# │ Id: 19c3b3f6-c356-48e8-b140-fb41b1a4605e                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
client.list_repos("myorg")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/.local/share/mamba/envs/agcm_environment_mac/lib/python3.12/site-packages/arraylake/api_utils.py:460, in handle_response(response)
#     459 try:
# --> 460     response.raise_for_status()
#     461 except httpx.RequestError as exc:
#
# File ~/.local/share/mamba/envs/agcm_environment_mac/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://api.earthmover.io/orgs/myorg/repos/paginated?page=1&size=100'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
from arraylake import Client
import zarr

client = Client()
repo = client.get_repo("mpocanes/era5-subscription")
session = repo.readonly_session(branch="main")
root = zarr.open_group(session.store, zarr_format=3, mode="r")

# %%
# print(xr.__version__)  # must be 2024 or beyond I have 2026

# %%
from arraylake import Client
import xarray as xr

client = Client()
repo = client.get_repo("mpocanes/era5-subscription")
session = repo.readonly_session(branch="main")
ds = xr.open_zarr(session.store, zarr_format=3)

ds
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*
